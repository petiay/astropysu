# %% [markdown]
# # Georgi

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table
plt.ion()
import os
# %matplotlib widget

# %%
plt.plot([1,2,3], [1, 2, 3])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Test interactive plot

# %% [markdown]
# $$ E = m c^2 $$

# %% [markdown]
# $$ R = \frac{1}{z+1}$$

# %%
s =  [1,4,5,8]

# %%
r = 4 + s[2]
print(r)
# Out:
# 9

# %%
e = "Georgi" + " Petrov"
print(e)
# Out:
# Georgi Petrov

# %%
e += "!"
print(e)
# Out:
# Georgi Petrov!

# %%
f = e.upper()

# %%
n1 = f.split(" ")[0]
n2 = f.split(" ")[1].split("!")[0]
print(n1)
print(n2)
# Out:
# GEORGI
# PETROV

# %%
l1 =[4, 5.5, "home"]

# %%
l1[0]
# Out:
# 4

# %%
l1[2][2]
# Out:
# 'm'

# %%
l1[1] = 16
print(l1)
# Out:
# [4, 16, 'home']

# %%
l1.append("school")
print(l1)
# Out:
# [4, 16, 'home', 'school']

# %%
l1.insert(1, 7)
print(l1)
# Out:
# [4, 7, 16, 'home', 'school']

# %%
l1.pop(1)
print(l1)
# Out:
# [4, 16, 'home', 'school']

# %%
l1.remove("school")
print(l1)
# Out:
# [4, 16, 'home']

# %%
l1[-1]
# Out:
# 'home'

# %%
l1[-2]
# Out:
# 16

# %%
l1.append("hello")
l1.append(3)
print(l1)
# Out:
# [4, 16, 'home', 'hello', 3]

# %%
g = 3.4
k = int (g)

# %%
print(k)
# Out:
# 3

# %%
print(type(k))
print(type(g))
print(type(l1[3]))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
w = int(round(float('5.5'))) + int(float('4.3'))
print(w)
# Out:
# 10

# %%
print("The result is", w)
# Out:
# The result is 10

# %%
print("The result is" + str(w))
# Out:
# The result is10

# %%
tr = True
fs = False

# %%
1 == 3
# Out:
# False

# %%
1 != 3
# Out:
# True

# %%
3 > 2
# Out:
# True

# %%
3 <= 3.4
# Out:
# True

# %%
x = 4.5 
result = (3.4 < x <= 6.6) or (x == 2)
print(result)
# Out:
# True

# %%
tt = (1, 2.3, 'spam')

# %%
tt [1]
# Out:
# 2.3

# %%
tt[:2]
# Out:
# (1, 2.3)

# %%
d = {'a':21, 'b':2, 'c':3}

# %%
d['a']
# Out:
# 21

# %%
d['c']
# Out:
# 3

# %%
d['r'] = 2.2
print(d)
# Out:
# {'a': 21, 'b': 2, 'c': 3, 'r': 2.2}

# %%
e = {}
e['a_string'] = 3.3
e[3445] = 2.2
e[complex(2,1)] = 'value'

# %%
print(e)
# Out:
# {'a_string': 3.3, 3445: 2.2, (2+1j): 'value'}

# %%
e[3445]
# Out:
# 2.2

# %%
e[complex(2,1)]
# Out:
# 'value'

# %%
"a" in d
# Out:
# True

# %%
"t" in d
# Out:
# False

# %%
ngc1667 = {'RA':72.154990, 'Dec':-6.320030, 'z': 0.015257, 'logFx':-13}

# %%
ngc1667['z']
# Out:
# 0.015257

# %%
ngc1667['logFx']
# Out:
# -13

# %%
ngc1667['Dec']
# Out:
# -6.32003

# %%
ngc1667['RA']
# Out:
# 72.15499
